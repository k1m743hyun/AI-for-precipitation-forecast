# %%
import os
os.chdir('drive/My Drive/Colab Notebooks/Project/AIFrenz_Season2')

# %%
pwd
# Out:
# '/content/drive/My Drive/Colab Notebooks/Project/AIFrenz_Season2'

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import *
from tensorflow.keras.regularizers import l1 , l2 , l1_l2
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split , KFold

# %%
np.random.seed(777)
tf.set_random_seed(777)

# %% [markdown]
# # Data

# %%
WIDTH = 40
HEIGHT = 40
CHANNEL = 9
IMAGE_SIZE = [WIDTH,HEIGHT,CHANNEL]
numOutputClass  = 1

file_path = 'data/dataset'
output_path = 'ckpt/output'
pred_path = 'ckpt/prediction'

NUM_TRAIN = 76345
NUM_TEST = 2416
BATCH_SIZE = 512
TOTAL_BATCH = int(NUM_TRAIN/BATCH_SIZE)
EPOCHS = 5

# %%
train_path = './data/dataset/'      ##### path 수정
image_path = 'train_images.npy'     ##### path 수정
data_path = 'train_data.npy'        ##### path 수정
label_path = 'train_labels.npy'     ##### path 수정

train_image = np.load(train_path+image_path)
#train_data = np.load(train_path+data_path)
train_label = np.load(train_path+label_path)
#train_all = np.concatenate([train_image,train_label],axis=3)

# %%
# [이미지 증식 코드]
# img_datagen = ImageDataGenerator(rotation_range=20,
#                                  width_shift_range=0.1,
#                                  height_shift_range=0.1)
# genTrain = img_datagen.flow(train, batch_size=train.shape[0], shuffle=False)[0]

# %%
# train_path = './data/dataset/'
# image_path = 'train_imageDataGenerator.npy'

# genData = np.load(train_path+image_path)

# train_image = genData[:,:,:,:9]
# train_label = genData[:,:,:,-1]
# del genData

# %%
# Load test_images
path = './data/dataset/' 
test_image = np.load(path+'test_images.npy')

# %%
x_train, x_test, y_train, y_test = train_test_split(train_image, train_label, test_size=0.05, random_state=777)
x_train.shape, y_train.shape, x_test.shape, y_test.shape

del train_image , train_label

# %%
# 0보다 작은 값이 포함된 데이터 삭제
y_train_ = y_train.reshape(-1, y_train.shape[1]*y_train.shape[2])

x_train = np.delete(x_train, np.where(y_train_ < 0)[0], axis=0)
y_train = np.delete(y_train, np.where(y_train_ < 0)[0], axis=0)
y_train = y_train.reshape(-1, x_train.shape[1], x_train.shape[2],1)

y_test = y_test.reshape(-1, y_test.shape[1], y_test.shape[2],1)

y_train_ = np.delete(y_train_, np.where(y_train_ < 0)[0], axis=0)

# # 강수량이 50이상인 데이터만 선택
# x_train = x_train[np.sum(y_train_ >= 0)]
# y_train = y_train[np.sum(y_train_ >= 50)]

x_train.shape, y_train.shape
# Out:
# ((72161, 40, 40, 9), (72161, 40, 40, 1))

# %%
#train_label_fit = train_label.reshape(-1,1600)

# %%
# def trainGenerator():
#     for i in range(len(train_label)):
#         Xdata = train_image[i,:,:,:]
#         ydata = train_label[i,:,:,:]
#         ydata = ydata.reshape([-1,40*40*1])

#         yield (Xdata , ydata)

# train_dataset = tf.data.Dataset.from_generator(trainGenerator,(tf.float32,tf.float32),(tf.TensorShape([40,40,9]),tf.TensorShape([None,40*40*1])))    ##### shape 수정

# train_dataset = train_dataset.repeat(EPOCHS).batch(BATCH_SIZE).prefetch(1)

# %% [markdown]
# # 평가 모델

# %%
from sklearn.metrics import f1_score

def mae(y_true, y_pred) :
    
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    
    y_true = y_true.reshape(1, -1)[0]
    
    y_pred = y_pred.reshape(1, -1)[0]
    
    over_threshold = y_true >= 0.1
    
    return np.mean(np.abs(y_true[over_threshold] - y_pred[over_threshold]))

def fscore(y_true, y_pred):
    
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    
    y_true = y_true.reshape(1, -1)[0]
    
    y_pred = y_pred.reshape(1, -1)[0]
    
    remove_NAs = y_true >= 0
    
    y_true = np.where(y_true[remove_NAs] >= 0.1, 1, 0)
    
    y_pred = np.where(y_pred[remove_NAs] >= 0.1, 1, 0)
    
    return(f1_score(y_true, y_pred))

def maeOverFscore(y_true, y_pred):
    return mae(y_true, y_pred) / (fscore(y_true, y_pred) + 1e-07)

def fscore_keras(y_true, y_pred):
    score = tf.py_function(func=fscore, inp=[y_true, y_pred], Tout=tf.float32, name='fscore_keras')
    return score

def maeOverFscore_keras(y_true, y_pred):
    score = tf.py_function(func=maeOverFscore, inp=[y_true, y_pred], Tout=tf.float32,  name='custom_mse') 
    return score

# %%
def mae_over_fscore(y_true, y_pred):
    '''
    y_true: sample_submission.csv 형태의 실제 값
    y_pred: sample_submission.csv 형태의 예측 값
    '''

    y_true = np.array(y_true)
    y_true = y_true.reshape(1, -1)[0]  
    
    y_pred = np.array(y_pred)
    y_pred = y_pred.reshape(1, -1)[0]
    
    # 실제값이 0.1 이상인 픽셀의 위치 확인
    IsGreaterThanEqualTo_PointOne = y_true >= 0.1
    
    # 실제 값에 결측값이 없는 픽셀의 위치 확인 
    IsNotMissing = y_true >= 0
    
    # mae 계산
    mae = np.mean(np.abs(y_true[IsGreaterThanEqualTo_PointOne] - y_pred[IsGreaterThanEqualTo_PointOne]))
    
    # f1_score 계산 위해, 실제값에 결측값이 없는 픽셀에 대해 1과 0으로 값 변환
    y_true = np.where(y_true[IsNotMissing] >= 0.1, 1, 0)
    
    y_pred = np.where(y_pred[IsNotMissing] >= 0.1, 1, 0)
    
    # f1_score 계산    
    f_score = f1_score(y_true, y_pred) 
    
    # f1_score가 0일 나올 경우를 대비하여 소량의 값 (1e-07) 추가 
    return mae / (f_score + 1e-07)

# %% [markdown]
# # Model

# %% [markdown]
# ## Pre Module

# %%
def res_vanil_conv2d(inputs,filter_size,kernel_size=3):
    conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(1,1),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(inputs)
    conv = BatchNormalization()(conv)
    conv = Dropout(0.25)(conv)
    conv = ReLU()(conv)

    return conv

def res_block(steps,conv,shortcut,filter_size,kernel_size=3):
    step = 0
    shortcut = conv

    for step in range(steps):
        if step == 0:
            conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(2,2),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(conv)
            conv = BatchNormalization()(conv)
            conv = ReLU()(conv)

            shortcut = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(2,2),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(shortcut)
            shortcut = BatchNormalization()(shortcut)

            conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(1,1),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(conv)
            conv = ReLU()(conv)
            
            conv_cat = Add()([conv,shortcut])
            conv = ReLU()(conv_cat)

            next_shortcut = conv

        else:
            conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(1,1),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(conv)
            conv = ReLU()(conv) 
            
            conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(1,1),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(conv)

            conv_cat = Add()([conv,next_shortcut])
            conv = ReLU()(conv_cat)

    return conv , shortcut

# %%
def Res_Net():
    res_inputs = Input([40,40,9])

    # Layer 1 : 7x7 64 , 2s
    conv = res_vanil_conv2d(res_inputs,16,5)
    shortcut = conv

    # maxpool 3x3 64 , 2s

    # # Layer 2/3/4/5 : 3x3 64 _ 3 / 3x3 128 _ 4 / 3x3 256 _ 6 / 3x3 512 _ 3
    filter_size = 16
    steps = [3,4,6,3]
    for i in steps:
        conv , shortcut = res_block(i,conv,shortcut,filter_size)
        filter_size = filter_size * 2

    output = res_vanil_conv2d(conv,1,1)


    model = Model(inputs=res_inputs , outputs=output)

    return model

# %%
resnet = Res_Net()
resnet.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_8 (InputLayer)            [(None, 40, 40, 9)]  0
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 40, 40, 16)   3616        input_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 40, 40, 16)   64          conv2d_80[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 40, 40, 16)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# re_lu_76 (ReLU)                 (None, 40, 40, 16)   0           dropout_10[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 20, 20, 16)   64          conv2d_81[0][0]
# __________________________________________________________________________________________________
# re_lu_77 (ReLU)                 (None, 20, 20, 16)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_77[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_76[0][0]
# __________________________________________________________________________________________________
# re_lu_78 (ReLU)                 (None, 20, 20, 16)   0           conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 20, 20, 16)   64          conv2d_82[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 20, 20, 16)   0           re_lu_78[0][0]
#                                                                  batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# re_lu_79 (ReLU)                 (None, 20, 20, 16)   0           add_27[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_79[0][0]
# __________________________________________________________________________________________________
# re_lu_80 (ReLU)                 (None, 20, 20, 16)   0           conv2d_84[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_80[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 20, 20, 16)   0           conv2d_85[0][0]
#                                                                  re_lu_79[0][0]
# __________________________________________________________________________________________________
# re_lu_81 (ReLU)                 (None, 20, 20, 16)   0           add_28[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_81[0][0]
# __________________________________________________________________________________________________
# re_lu_82 (ReLU)                 (None, 20, 20, 16)   0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 20, 20, 16)   2320        re_lu_82[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 20, 20, 16)   0           conv2d_87[0][0]
#                                                                  re_lu_79[0][0]
# __________________________________________________________________________________________________
# re_lu_83 (ReLU)                 (None, 20, 20, 16)   0           add_29[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 10, 10, 32)   4640        re_lu_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 10, 10, 32)   128         conv2d_88[0][0]
# __________________________________________________________________________________________________
# re_lu_84 (ReLU)                 (None, 10, 10, 32)   0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_84[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 10, 10, 32)   4640        re_lu_83[0][0]
# __________________________________________________________________________________________________
# re_lu_85 (ReLU)                 (None, 10, 10, 32)   0           conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 10, 10, 32)   128         conv2d_89[0][0]
# __________________________________________________________________________________________________
# add_30 (Add)                    (None, 10, 10, 32)   0           re_lu_85[0][0]
#                                                                  batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# re_lu_86 (ReLU)                 (None, 10, 10, 32)   0           add_30[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_86[0][0]
# __________________________________________________________________________________________________
# re_lu_87 (ReLU)                 (None, 10, 10, 32)   0           conv2d_91[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_87[0][0]
# __________________________________________________________________________________________________
# add_31 (Add)                    (None, 10, 10, 32)   0           conv2d_92[0][0]
#                                                                  re_lu_86[0][0]
# __________________________________________________________________________________________________
# re_lu_88 (ReLU)                 (None, 10, 10, 32)   0           add_31[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_88[0][0]
# __________________________________________________________________________________________________
# re_lu_89 (ReLU)                 (None, 10, 10, 32)   0           conv2d_93[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_89[0][0]
# __________________________________________________________________________________________________
# add_32 (Add)                    (None, 10, 10, 32)   0           conv2d_94[0][0]
#                                                                  re_lu_86[0][0]
# __________________________________________________________________________________________________
# re_lu_90 (ReLU)                 (None, 10, 10, 32)   0           add_32[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_90[0][0]
# __________________________________________________________________________________________________
# re_lu_91 (ReLU)                 (None, 10, 10, 32)   0           conv2d_95[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 10, 10, 32)   9248        re_lu_91[0][0]
# __________________________________________________________________________________________________
# add_33 (Add)                    (None, 10, 10, 32)   0           conv2d_96[0][0]
#                                                                  re_lu_86[0][0]
# __________________________________________________________________________________________________
# re_lu_92 (ReLU)                 (None, 10, 10, 32)   0           add_33[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 5, 5, 64)     18496       re_lu_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 5, 5, 64)     256         conv2d_97[0][0]
# __________________________________________________________________________________________________
# re_lu_93 (ReLU)                 (None, 5, 5, 64)     0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 5, 5, 64)     36928       re_lu_93[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 5, 5, 64)     18496       re_lu_92[0][0]
# __________________________________________________________________________________________________
# re_lu_94 (ReLU)                 (None, 5, 5, 64)     0           conv2d_99[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 5, 5, 64)     256         conv2d_98[0][0]
# __________________________________________________________________________________________________
# add_34 (Add)                    (None, 5, 5, 64)     0           re_lu_94[0][0]
#                                                                  batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# re_lu_95 (ReLU)                 (None, 5, 5, 64)     0           add_34[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_96 (ReLU)                 (None, 5, 5, 64)     0           conv2d_100[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_96[0][0]
# __________________________________________________________________________________________________
# add_35 (Add)                    (None, 5, 5, 64)     0           conv2d_101[0][0]
#                                                                  re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_97 (ReLU)                 (None, 5, 5, 64)     0           add_35[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_97[0][0]
# __________________________________________________________________________________________________
# re_lu_98 (ReLU)                 (None, 5, 5, 64)     0           conv2d_102[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_98[0][0]
# __________________________________________________________________________________________________
# add_36 (Add)                    (None, 5, 5, 64)     0           conv2d_103[0][0]
#                                                                  re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_99 (ReLU)                 (None, 5, 5, 64)     0           add_36[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_99[0][0]
# __________________________________________________________________________________________________
# re_lu_100 (ReLU)                (None, 5, 5, 64)     0           conv2d_104[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_100[0][0]
# __________________________________________________________________________________________________
# add_37 (Add)                    (None, 5, 5, 64)     0           conv2d_105[0][0]
#                                                                  re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_101 (ReLU)                (None, 5, 5, 64)     0           add_37[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_101[0][0]
# __________________________________________________________________________________________________
# re_lu_102 (ReLU)                (None, 5, 5, 64)     0           conv2d_106[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_102[0][0]
# __________________________________________________________________________________________________
# add_38 (Add)                    (None, 5, 5, 64)     0           conv2d_107[0][0]
#                                                                  re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_103 (ReLU)                (None, 5, 5, 64)     0           add_38[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_103[0][0]
# __________________________________________________________________________________________________
# re_lu_104 (ReLU)                (None, 5, 5, 64)     0           conv2d_108[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 5, 5, 64)     36928       re_lu_104[0][0]
# __________________________________________________________________________________________________
# add_39 (Add)                    (None, 5, 5, 64)     0           conv2d_109[0][0]
#                                                                  re_lu_95[0][0]
# __________________________________________________________________________________________________
# re_lu_105 (ReLU)                (None, 5, 5, 64)     0           add_39[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 3, 3, 128)    73856       re_lu_105[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 3, 3, 128)    512         conv2d_110[0][0]
# __________________________________________________________________________________________________
# re_lu_106 (ReLU)                (None, 3, 3, 128)    0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 3, 3, 128)    147584      re_lu_106[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 3, 3, 128)    73856       re_lu_105[0][0]
# __________________________________________________________________________________________________
# re_lu_107 (ReLU)                (None, 3, 3, 128)    0           conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 3, 3, 128)    512         conv2d_111[0][0]
# __________________________________________________________________________________________________
# add_40 (Add)                    (None, 3, 3, 128)    0           re_lu_107[0][0]
#                                                                  batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# re_lu_108 (ReLU)                (None, 3, 3, 128)    0           add_40[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 3, 3, 128)    147584      re_lu_108[0][0]
# __________________________________________________________________________________________________
# re_lu_109 (ReLU)                (None, 3, 3, 128)    0           conv2d_113[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 3, 3, 128)    147584      re_lu_109[0][0]
# __________________________________________________________________________________________________
# add_41 (Add)                    (None, 3, 3, 128)    0           conv2d_114[0][0]
#                                                                  re_lu_108[0][0]
# __________________________________________________________________________________________________
# re_lu_110 (ReLU)                (None, 3, 3, 128)    0           add_41[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 3, 3, 128)    147584      re_lu_110[0][0]
# __________________________________________________________________________________________________
# re_lu_111 (ReLU)                (None, 3, 3, 128)    0           conv2d_115[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 3, 3, 128)    147584      re_lu_111[0][0]
# __________________________________________________________________________________________________
# add_42 (Add)                    (None, 3, 3, 128)    0           conv2d_116[0][0]
#                                                                  re_lu_108[0][0]
# __________________________________________________________________________________________________
# re_lu_112 (ReLU)                (None, 3, 3, 128)    0           add_42[0][0]
# __________________________________________________________________________________________________
# conv2d_117 (Conv2D)             (None, 3, 3, 1)      129         re_lu_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 3, 3, 1)      4           conv2d_117[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 3, 3, 1)      0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# re_lu_113 (ReLU)                (None, 3, 3, 1)      0           dropout_11[0][0]
# ==================================================================================================
# Total params: 1,424,821
# Trainable params: 1,423,827
# Non-trainable params: 994
# __________________________________________________________________________________________________

# %% [markdown]
# ## Version 2

# %%
def conv2d(inputs,filter_size,kernel_size=3):
    conv = Conv2D(filters=filter_size,kernel_size=kernel_size,strides=(1,1),padding='same', activation=None,use_bias=True,kernel_initializer='glorot_normal')(inputs)
    conv = BatchNormalization()(conv)
    conv = ReLU()(conv)
    
    return conv

def maxpool(conv):
    conv = MaxPool2D(pool_size=(2,2),strides=None,padding='valid')(conv)
    return conv

def deconv2d(conv,filter_size):
    conv = Conv2DTranspose(filters=filter_size,kernel_size=(3,3),strides=(2,2),padding='same',dilation_rate=(1,1),activation=None,use_bias=True,kernel_initializer='glorot_normal')(conv)

    return conv

def concat(deconv,conv):
    concat = Concatenate(axis=3)([deconv,conv])

    return concat

def Contracting_Path(inputs,layers=3,base_feature=32):
    dw_conv_list = []
    feature = base_feature

    # Contraction Path
    ## Conv Layer 1
    conv = conv2d(inputs,base_feature)
    conv = conv2d(conv,base_feature)
    dw_conv_list.append(conv)

    conv = maxpool(conv)

    # Conv Layer 2
    for layer in range(layers-2):
        feature = feature * 2
        conv = conv2d(conv,feature)
        conv = conv2d(conv,feature)
        dw_conv_list.append(conv)

        conv = maxpool(conv)

    ## Conv Layer 3
    feature = feature * 2
    conv = conv2d(conv,feature)
    conv = conv2d(conv,feature)

    return conv , dw_conv_list

def Expanding_Path(conv,dw_conv_list):
    
    while len(dw_conv_list) != 0:
        dw_conv = dw_conv_list.pop()
        feature = dw_conv.shape[3]

        deconv = deconv2d(conv,feature)
        conv_cat = concat(deconv,dw_conv)

        conv = conv2d(conv_cat , (conv_cat.shape[3]//2))
        conv = conv2d(conv , (conv.shape[3]))

    return conv

# %%
def Unet():
    inputs = Input([40,40,9])

    conv , dw_conv_list = Contracting_Path(inputs,layers=4,base_feature=32)

    conv = Expanding_Path(conv,dw_conv_list)

    output = conv2d(conv,1)

    model = Model(inputs=inputs,outputs=output)
    model.compile(loss="mae", optimizer="adam", metrics=[fscore_keras,maeOverFscore_keras])

    return model

# %%
model = Unet()
model.summary()

# %% [markdown]
# # Training

# %%
# ReduceLROnPlateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',patience=3) # factor=0.05
# EarlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=7,restore_best_weights=True)

# callbackList = [EarlyStop,ReduceLROnPlateau]

# hist = model.fit(x_train,y_train,epochs=50,batch_size=512,validation_split=0.25, callbacks = callbackList, verbose=1)

# %%
def train_model(x_data, y_data, k, s):
    models = []
    k_fold = KFold(n_splits=k, shuffle=True, random_state=777)
    
    model_number = 0
    for train_idx, val_idx in k_fold.split(x_data):
        if model_number != s:
            x_trainImg, y_trainLabel = x_data[train_idx], y_data[train_idx]
            x_valImg, y_valLabel = x_data[val_idx], y_data[val_idx]

            model = Unet()

            ReduceLROnPlateau = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',patience=3) # factor=0.05
            EarlyStop = tf.keras.callbacks.EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)
            #ModelCkpt = tf.keras.callbacks.ModelCheckpoint(filepath='ckpt/Unet_' + str(model_number)+'.h5',monitor='val_loss',save_best_only=True)
            callbackList = [EarlyStop,ReduceLROnPlateau]
            
            print('val:',model_number+1)
            model.fit(x_trainImg, y_trainLabel, epochs=50, batch_size=512, validation_data=(x_valImg, y_valLabel), callbacks=callbackList)
            models.append(model)

            del x_trainImg , y_trainLabel , x_valImg , y_valLabel
            model_number += 1
            
    return models

# %%
n = 0
k = 5
preds = []

models = train_model(x_train, y_train, k=k, s=4)

for model in models:
    model.save('ckpt/Unet_val_'+str(n)+'.h5')
    n += 1

for model in models:
    preds.append(model.predict(x_test))
    print(mae_over_fscore(y_test, preds[-1]))

preds = np.array(preds)
pred = np.array(preds).mean(axis=0)
print(mae_over_fscore(y_test, pred))
# Out:
# val: 1
# Train on 57728 samples, validate on 14433 samples
# Epoch 1/50
# 57728/57728 [==============================] - 65s 1ms/sample - loss: 0.1387 - fscore_keras: 0.5835 - maeOverFscore_keras: 3.1879 - val_loss: 0.1492 - val_fscore_keras: 0.0346 - val_maeOverFscore_keras: 66.4614
# Epoch 2/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.1080 - fscore_keras: 0.6636 - maeOverFscore_keras: 2.3367 - val_loss: 0.1435 - val_fscore_keras: 0.2066 - val_maeOverFscore_keras: 10.3648
# Epoch 3/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.1038 - fscore_keras: 0.6818 - maeOverFscore_keras: 2.1874 - val_loss: 0.1566 - val_fscore_keras: 0.2798 - val_maeOverFscore_keras: 6.7073
# Epoch 4/50
# 57728/57728 [==============================] - 65s 1ms/sample - loss: 0.1016 - fscore_keras: 0.6932 - maeOverFscore_keras: 2.1032 - val_loss: 0.1410 - val_fscore_keras: 0.2577 - val_maeOverFscore_keras: 7.7896
# Epoch 5/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0996 - fscore_keras: 0.7048 - maeOverFscore_keras: 2.0305 - val_loss: 0.1197 - val_fscore_keras: 0.5248 - val_maeOverFscore_keras: 3.3056
# Epoch 6/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0983 - fscore_keras: 0.7132 - maeOverFscore_keras: 1.9787 - val_loss: 0.1212 - val_fscore_keras: 0.4000 - val_maeOverFscore_keras: 4.4669
# Epoch 7/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0975 - fscore_keras: 0.7173 - maeOverFscore_keras: 1.9463 - val_loss: 0.1176 - val_fscore_keras: 0.6241 - val_maeOverFscore_keras: 2.6451
# Epoch 8/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0966 - fscore_keras: 0.7233 - maeOverFscore_keras: 1.9194 - val_loss: 0.1306 - val_fscore_keras: 0.6603 - val_maeOverFscore_keras: 2.7611
# Epoch 9/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0963 - fscore_keras: 0.7260 - maeOverFscore_keras: 1.9031 - val_loss: 0.1140 - val_fscore_keras: 0.5814 - val_maeOverFscore_keras: 2.8729
# Epoch 10/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0949 - fscore_keras: 0.7348 - maeOverFscore_keras: 1.8523 - val_loss: 0.1052 - val_fscore_keras: 0.6722 - val_maeOverFscore_keras: 2.1955
# Epoch 11/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0951 - fscore_keras: 0.7341 - maeOverFscore_keras: 1.8523 - val_loss: 0.1084 - val_fscore_keras: 0.6596 - val_maeOverFscore_keras: 2.2517
# Epoch 12/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0938 - fscore_keras: 0.7412 - maeOverFscore_keras: 1.8153 - val_loss: 0.2316 - val_fscore_keras: 0.3213 - val_maeOverFscore_keras: 4.7171
# Epoch 13/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0937 - fscore_keras: 0.7418 - maeOverFscore_keras: 1.8087 - val_loss: 0.1231 - val_fscore_keras: 0.3770 - val_maeOverFscore_keras: 4.8315
# Epoch 14/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0919 - fscore_keras: 0.7526 - maeOverFscore_keras: 1.7486 - val_loss: 0.0953 - val_fscore_keras: 0.7214 - val_maeOverFscore_keras: 1.8754
# Epoch 15/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0917 - fscore_keras: 0.7527 - maeOverFscore_keras: 1.7459 - val_loss: 0.0952 - val_fscore_keras: 0.7367 - val_maeOverFscore_keras: 1.8438
# Epoch 16/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0913 - fscore_keras: 0.7541 - maeOverFscore_keras: 1.7347 - val_loss: 0.0957 - val_fscore_keras: 0.7584 - val_maeOverFscore_keras: 1.7598
# Epoch 17/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0913 - fscore_keras: 0.7541 - maeOverFscore_keras: 1.7344 - val_loss: 0.0945 - val_fscore_keras: 0.7371 - val_maeOverFscore_keras: 1.8484
# Epoch 18/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0912 - fscore_keras: 0.7545 - maeOverFscore_keras: 1.7310 - val_loss: 0.0980 - val_fscore_keras: 0.7406 - val_maeOverFscore_keras: 1.8591
# Epoch 19/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0911 - fscore_keras: 0.7557 - maeOverFscore_keras: 1.7235 - val_loss: 0.0968 - val_fscore_keras: 0.7537 - val_maeOverFscore_keras: 1.7858
# Epoch 20/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0911 - fscore_keras: 0.7554 - maeOverFscore_keras: 1.7239 - val_loss: 0.0951 - val_fscore_keras: 0.7616 - val_maeOverFscore_keras: 1.7392
# Epoch 21/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0905 - fscore_keras: 0.7566 - maeOverFscore_keras: 1.7132 - val_loss: 0.0932 - val_fscore_keras: 0.7586 - val_maeOverFscore_keras: 1.7286
# Epoch 22/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0905 - fscore_keras: 0.7572 - maeOverFscore_keras: 1.7096 - val_loss: 0.0933 - val_fscore_keras: 0.7554 - val_maeOverFscore_keras: 1.7487
# Epoch 23/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0904 - fscore_keras: 0.7564 - maeOverFscore_keras: 1.7104 - val_loss: 0.0933 - val_fscore_keras: 0.7596 - val_maeOverFscore_keras: 1.7308
# Epoch 24/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0904 - fscore_keras: 0.7572 - maeOverFscore_keras: 1.7078 - val_loss: 0.0934 - val_fscore_keras: 0.7554 - val_maeOverFscore_keras: 1.7395
# Epoch 25/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0904 - fscore_keras: 0.7574 - maeOverFscore_keras: 1.7077 - val_loss: 0.0931 - val_fscore_keras: 0.7570 - val_maeOverFscore_keras: 1.7165
# Epoch 26/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0903 - fscore_keras: 0.7570 - maeOverFscore_keras: 1.7075 - val_loss: 0.0931 - val_fscore_keras: 0.7584 - val_maeOverFscore_keras: 1.7509
# Epoch 27/50
# 57728/57728 [==============================] - 62s 1ms/sample - loss: 0.0903 - fscore_keras: 0.7577 - maeOverFscore_keras: 1.7070 - val_loss: 0.0931 - val_fscore_keras: 0.7583 - val_maeOverFscore_keras: 1.7339
# Epoch 28/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0903 - fscore_keras: 0.7570 - maeOverFscore_keras: 1.7082 - val_loss: 0.0931 - val_fscore_keras: 0.7574 - val_maeOverFscore_keras: 1.7350
# Epoch 29/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0904 - fscore_keras: 0.7575 - maeOverFscore_keras: 1.7078 - val_loss: 0.0931 - val_fscore_keras: 0.7589 - val_maeOverFscore_keras: 1.7210
# Epoch 30/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0903 - fscore_keras: 0.7574 - maeOverFscore_keras: 1.7077 - val_loss: 0.0931 - val_fscore_keras: 0.7572 - val_maeOverFscore_keras: 1.7214
# Epoch 31/50
# 57728/57728 [==============================] - 63s 1ms/sample - loss: 0.0903 - fscore_keras: 0.7574 - maeOverFscore_keras: 1.7079 - val_loss: 0.0931 - val_fscore_keras: 0.7598 - val_maeOverFscore_keras: 1.7151
# Epoch 32/50
# 57728/57728 [==============================] - 64s 1ms/sample - loss: 0.0904 - fscore_keras: 0.7571 - maeOverFscore_keras: 1.7074 - val_loss: 0.0931 - val_fscore_keras: 0.7585 - val_maeOverFscore_keras: 1.7256
# val: 2
# Train on 57729 samples, validate on 14432 samples
# Epoch 1/50
# 57729/57729 [==============================] - 67s 1ms/sample - loss: 0.1356 - fscore_keras: 0.5721 - maeOverFscore_keras: 3.3294 - val_loss: 0.1439 - val_fscore_keras: 0.0813 - val_maeOverFscore_keras: 26.8344
# Epoch 2/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.1087 - fscore_keras: 0.6726 - maeOverFscore_keras: 2.2942 - val_loss: 0.1409 - val_fscore_keras: 0.0695 - val_maeOverFscore_keras: 31.3836
# Epoch 3/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.1047 - fscore_keras: 0.6865 - maeOverFscore_keras: 2.1692 - val_loss: 0.1383 - val_fscore_keras: 0.1927 - val_maeOverFscore_keras: 10.9627
# Epoch 4/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.1021 - fscore_keras: 0.7031 - maeOverFscore_keras: 2.0649 - val_loss: 0.1292 - val_fscore_keras: 0.3611 - val_maeOverFscore_keras: 5.4468
# Epoch 5/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.1008 - fscore_keras: 0.7112 - maeOverFscore_keras: 2.0124 - val_loss: 0.1146 - val_fscore_keras: 0.4175 - val_maeOverFscore_keras: 4.1738
# Epoch 6/50
# 57729/57729 [==============================] - 63s 1ms/sample - loss: 0.0989 - fscore_keras: 0.7218 - maeOverFscore_keras: 1.9514 - val_loss: 0.1201 - val_fscore_keras: 0.2942 - val_maeOverFscore_keras: 6.2667
# Epoch 7/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0984 - fscore_keras: 0.7228 - maeOverFscore_keras: 1.9329 - val_loss: 0.1048 - val_fscore_keras: 0.6944 - val_maeOverFscore_keras: 2.1549
# Epoch 8/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0976 - fscore_keras: 0.7276 - maeOverFscore_keras: 1.9057 - val_loss: 0.1278 - val_fscore_keras: 0.3979 - val_maeOverFscore_keras: 4.5868
# Epoch 9/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0969 - fscore_keras: 0.7307 - maeOverFscore_keras: 1.8826 - val_loss: 0.1087 - val_fscore_keras: 0.5986 - val_maeOverFscore_keras: 2.7382
# Epoch 10/50
# 57729/57729 [==============================] - 63s 1ms/sample - loss: 0.0957 - fscore_keras: 0.7381 - maeOverFscore_keras: 1.8437 - val_loss: 0.1501 - val_fscore_keras: 0.5098 - val_maeOverFscore_keras: 3.5370
# Epoch 11/50
# 57729/57729 [==============================] - 63s 1ms/sample - loss: 0.0941 - fscore_keras: 0.7447 - maeOverFscore_keras: 1.7967 - val_loss: 0.0963 - val_fscore_keras: 0.6817 - val_maeOverFscore_keras: 2.0933
# Epoch 12/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0936 - fscore_keras: 0.7482 - maeOverFscore_keras: 1.7774 - val_loss: 0.0937 - val_fscore_keras: 0.7352 - val_maeOverFscore_keras: 1.8177
# Epoch 13/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0936 - fscore_keras: 0.7492 - maeOverFscore_keras: 1.7733 - val_loss: 0.0925 - val_fscore_keras: 0.7347 - val_maeOverFscore_keras: 1.8317
# Epoch 14/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0932 - fscore_keras: 0.7503 - maeOverFscore_keras: 1.7656 - val_loss: 0.0928 - val_fscore_keras: 0.7375 - val_maeOverFscore_keras: 1.8456
# Epoch 15/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0931 - fscore_keras: 0.7502 - maeOverFscore_keras: 1.7646 - val_loss: 0.0914 - val_fscore_keras: 0.7446 - val_maeOverFscore_keras: 1.8200
# Epoch 16/50
# 57729/57729 [==============================] - 62s 1ms/sample - loss: 0.0932 - fscore_keras: 0.7504 - maeOverFscore_keras: 1.7611 - val_loss: 0.0911 - val_fscore_keras: 0.7362 - val_maeOverFscore_keras: 1.7977
# Epoch 17/50
# 57344/57729 [============================>.] - ETA: 0s - loss: 0.0931 - fscore_keras: 0.7510 - maeOverFscore_keras: 1.7604
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-58-c864918493bc> in <module>()
#       3 preds = []
#       4
# ----> 5 models = train_model(x_train, y_train, k=k, s=4)
#       6
#       7 for model in models:
#
# <ipython-input-57-5f1dcc3ac9c9> in train_model(x_data, y_data, k, s)
#      17
#      18             print('val:',model_number+1)
# ---> 19             model.fit(x_trainImg, y_trainLabel, epochs=50, batch_size=512, validation_data=(x_valImg, y_valLabel), callbacks=callbackList)
#      20             models.append(model)
#      21
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     438           validation_in_fit=True,
#     439           prepared_feed_values_from_dataset=(val_iterator is not None),
# --> 440           steps_name='validation_steps')
#     441       if not isinstance(val_results, list):
#     442         val_results = [val_results]
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3474
#    3475     fetched = self._callable_fn(*array_vals,
# -> 3476                                 run_metadata=self.run_metadata)
#    3477     self._call_fetch_callbacks(fetched[-len(self._fetches):])
#    3478     output_structure = nest.pack_sequence_as(
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/client/session.py in __call__(self, *args, **kwargs)
#    1470         ret = tf_session.TF_SessionRunCallable(self._session._session,
#    1471                                                self._handle, args,
# -> 1472                                                run_metadata_ptr)
#    1473         if run_metadata:
#    1474           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
# model.evaluate(x_test,y_test,verbose=1)

# %%
# val test
preds = []
for model in models:
    preds.append(model.predict(x_test))
    print(mae_over_fscore(y_test, preds[-1]))

preds = np.array(preds)
predictions = preds.mean(axis=0)
print(mae_over_fscore(y_test, predictions))

# %%
# prediction
preds = []
for model in models:
    preds.append(model.predict(test_image))

preds = np.array(preds)
prediction = np.array(preds).mean(axis=0)

# %%
# submission = pd.read_csv('data/sample_submission.csv')
# submission.iloc[:,1:] = prediction.reshape([-1,1600])
# submission.to_csv('data/U_Net_ver1_2_20200521.csv', index=False)

# %%
# model.save('U_Net_200521_ver_1_2.h5')
